# %%
import pandas as pd
import numpy as np

# %%
# first row contains "Report Date"
df = pd.read_csv('data/UK-Sanctions-List.csv', skiprows=1)
# Out:
# C:\Users\44743\AppData\Local\Temp\ipykernel_9116\4095782856.py:1: DtypeWarning: Columns (0: IMO number, 1: Current owner/operator (s), 2: Previous owner/operator (s), 3: Current believed flag of ship, 4: Previous flags, 5: Type of ship) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/UK-Sanctions-List.csv', skiprows=1)

# %%
df.head()
# Out:
#   Last Updated Unique ID  OFSI Group ID UN Reference Number  \
# 0   16/04/2026   AFG0001        12703.0             TAe.010
# 1   16/04/2026   AFG0001        12703.0             TAe.010
# 2   16/04/2026   AFG0001        12703.0             TAe.010
# 3   16/04/2026   AFG0001        12703.0             TAe.010
# 4   16/04/2026   AFG0001        12703.0             TAe.010
#
#                                        Name 6 Name 1 Name 2 Name 3 Name 4  \
# 0  HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE    NaN    NaN    NaN    NaN
# 1  HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE    NaN    NaN    NaN    NaN
# 2  HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE    NaN    NaN    NaN    NaN
# 3  HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE    NaN    NaN    NaN    NaN
# 4  HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE    NaN    NaN    NaN    NaN
#
#   Name 5  ... IMO number Current owner/operator (s)  \
# 0    NaN  ...        NaN                        NaN
# ...

# %%
df.shape
# Out:
# (57387, 58)

# %%
df.describe()
# Out:
#        OFSI Group ID  Tonnage of ship  Length of ship   Year Built  \
# count   54805.000000       402.000000      246.000000   676.000000
# mean    12413.723638     31653.631841      110.513618  2000.585799
# std      2538.523624     38325.080969       42.897142    10.524330
# min      6894.000000       748.000000       58.000000  1973.000000
# 25%     11199.000000      3037.000000       85.000000  1995.000000
# 50%     12446.000000      6788.000000       98.000000  2004.000000
# 75%     13702.000000     60303.000000      116.000000  2007.000000
# max     17285.000000    164565.000000      274.500000  2024.000000
#
#        Hull identification number (HIN)
# count                               0.0
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 57387 entries, 0 to 57386
# Data columns (total 58 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Last Updated                                57387 non-null  str
#  1   Unique ID                                   57387 non-null  str
#  2   OFSI Group ID                               54805 non-null  float64
#  3   UN Reference Number                         20532 non-null  str
#  4   Name 6                                      57275 non-null  str
#  5   Name 1                                      24088 non-null  str
#  6   Name 2                                      12242 non-null  str
#  7   Name 3                                      2583 non-null   str
#  8   Name 4                                      480 non-null    str
#  9   Name 5                                      101 non-null    str
# ...

# %%
df.isnull().sum()
# Out:
# Last Updated                                      0
# Unique ID                                         0
# OFSI Group ID                                  2582
# UN Reference Number                           36855
# Name 6                                          112
# Name 1                                        33299
# Name 2                                        45145
# Name 3                                        54804
# Name 4                                        56907
# Name 5                                        57286
# Name type                                        64
# Alias strength                                44405
# Title                                         54925
# Name non-latin script                         49509
# Non-latin script type                         53343
# Non-latin script language                     53785
# Regime Name                                       0
# Designation Type                                  0
# ...
